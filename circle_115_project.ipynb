# %% [markdown]
# <a href="https://colab.research.google.com/github/Code-Ebullient/circle_115_matlab_project/blob/main/circle_115_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##**Circle 115 Project using Matplotlib Python Package**

# %% [markdown]
# **MATPLOTLIB**
#
# Is one of the data visualization tool used in Python Programming Language. It makes use of plots and graphs of which take numerical data as input and display output in the form of charts, figures and tables. The altermate aim of using this tool is to communicate information and tell a story visually.
#
# It can export visualizations to all of the common formats like PDF, SVG, JPG, PNG, BMP and GIF. It also create popular visualization types – line plot, scatter plot, histogram, bar chart, error charts, pie chart, box plot, et cetera. Matplotlib also supports 3D plotting.

# %% [markdown]
# **INSTALLATION**
#
# Using IDEs, you must ensure that you hve python installed first before you can start matplotlib installation.
#
#
# <u>Using pip</u>
#
#
# ```
# pip install matplotlib
# ```
#
#
#
# <u>Using Jupyter Notebook or Google colab</u>
# ```
# import matplotlib.pyplot as plt
# ```

# %%
# A simple example
import numpy as np
import matplotlib.pyplot as plt

# np, plt are just an alias, it can be anything

x = np.linspace(0, 2, 100)

plt.plot(x, x, label='linear')
plt.plot(x, x**2, label='quadratic')
plt.plot(x, x**3, label='cubic')

plt.xlabel('x label')
plt.ylabel('y label')

plt.title("Simple Plot")

#plt.legend()

plt.show()

# %% [markdown]
# **PLOT TYPES**
#
# > <u>Pairwise Data</u> - plot of pairwise (x, y), tabular & functional data (Plot, Scatter, Bar, Stem, Fill_between, Stackplot, Stairs)
#
# > <u>Statistical Distribution</u> - Distribution of at least one variable (Hist, Boxplo, Errorbar, Violinplot, Eventplot, Hexbin, Pie, ecdf)
#
# > <u>Gridded Data</u> - Arrays & images (imshow, pcolormesh, contour, barbs, quiver, streamplot)
#
# > <u>Irregularly Gridded Data</u> - Plots of data Z<sub>x,</sub><sub>y</sub> on unstructured grids (tricontour, tripcolor, triplot)
#
# > <u>3D & Volumeric Data</u> - Plots of three dimensional xyz (scatter, plot_surface, plot_trisurf, voxels, plot_wirefram)

# %% [markdown]
# There are three applicable contexts for viewing Matplotlib plots,
# 1. using plotting from a script,
# 2. Plotting from an IPython shell
# 3. Plotting from a Jupyter notebook.
#
# Our focus here will be on the 3rd, which is using Jupyter Notebook.

# %% [markdown]
# **Matplotlib** graphs your data on **Figures**, each of which can contain one or more **Axes** (an area where points can be specified in terms of x-y coordinates).
#
# **pyplot.subplots** is the most commonly used interface. It create Figures with an Axes then **Axes.plot** is for drawing some data on the Axes.
#
# **pyplot interface** serves two purposes,
# 1. Spins up the backend and keep track of GUI windows
# 2. It serves as a global state for Axes & Artists that allows a short-form API to plotting methods.

# %%
# Example2 to explain how this works
fig, ax = plt.subplots() # This simply means to a figure with a single axes

# To display the information on the axes visually
ax.plot([1, 2, 3, 4], [1, 5, 3, 2], [2, 3, 5, 7])

# To give it a title
plt.title('Figure')

# To show it graphically
plt.show()

# %% [markdown]
# **A Figure** keeps track of all the child Axes.
#
# **An Axes** is an Artist attached to a figure that containes a region for ploting data (Two or more Axis).

# %% [markdown]
# ### Fig Anatomy
#
# ![fig_anatomy.png](data:image/png;base64,...)

# %% [markdown]
# **Saving the Plot**
#
# We can save the figures in a wide variety of formats.
#
#
#
# ```
# savefig()
# ```
#
#
# We can explore the contents of the file using the IPython Image object.
#
#
# ```
# from IPython.display import Image
#
# Image(‘fig.png’)
# ```
#
#
# In savefig() command, the file format is inferred from the extension of the given filename. Depending on the backend, many different file formats are available. So, we'll be using Titanic dataset for further examples.

# %%
import pandas as pd

data = r"/content/train.csv"
df = pd.read_csv(data)
df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
# Taking a closer look at all the columns
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
# To ascertain the no of survival against their Pclass using plt plot

X = df['Survived'].values
Y = df['Pclass'].values

A = df['Age'].values
S = df['Sex'].values

# %% [markdown]
# From the plot above, there's no much correlation. This means that the survival rate was not accrding to class.
#
# Then, let's see the correlation of all series.

# %%
df.corr()
# Out:
# <ipython-input-7-2f6f6606aa2c>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.035144  0.036847 -0.057527 -0.001652
# Survived       -0.005007  1.000000 -0.338481 -0.077221 -0.035322  0.081629
# Pclass         -0.035144 -0.338481  1.000000 -0.369226  0.083081  0.018443
# Age             0.036847 -0.077221 -0.369226  1.000000 -0.308247 -0.189119
# SibSp          -0.057527 -0.035322  0.083081 -0.308247  1.000000  0.414838
# Parch          -0.001652  0.081629  0.018443 -0.189119  0.414838  1.000000
# Fare            0.012658  0.257307 -0.549500  0.096067  0.159651  0.216225
#
#                  Fare
# PassengerId  0.012658
# Survived     0.257307
# Pclass      -0.549500
# ...

# %%
# Distribution of survival by gender
survBySex = df.groupby('Sex')['Survived'].mean()
survBySex
# Out:
# Sex
# female    0.742038
# male      0.188908
# Name: Survived, dtype: float64

# %%
# We will use plot here
# It's syntax is: Axes.plot(*args, scalex=True, scaley=True, data=None, **kwargs)
# It plots x v y as lines or marks


plt.plot(survBySex, label='linear')

plt.show()

# %%
# Using pie also on same output
# Pie plot has so many parameters
# Axes.pie(x, explode=None, labels=None, color=None etc)
# The fractional area of each wedge in array x is given by x/sum(x)

labels = ['Female', 'Male']
plt.pie(survBySex, labels=labels)

plt.show()

# %%
# Distribution of Survival by passenger class

survByClass = df.groupby('Pclass')['Survived'].mean()
survByClass
# Out:
# Pclass
# 1    0.629630
# 2    0.472826
# 3    0.242363
# Name: Survived, dtype: float64

# %%
# Making the color of our pie plot none, Matplotlib will automatically assign colors to our output as shown
labels = [1, 2, 3]
plt.pie(survByClass, labels=labels)

plt.show()

# %%
# How does the survival rate vary for different age groups (e.g., children, adults, seniors)?

age_groups = pd.cut(df['Age'], bins=[0, 18, 35, 60, float('inf')],
                    labels=['Child', 'Adult','Middle Aged' ,'Senior'])
ageGrp = df.groupby(age_groups)['Survived'].mean()
ageGrp
# Out:
# Age
# Child          0.503597
# Adult          0.382682
# Middle Aged    0.400000
# Senior         0.227273
# Name: Survived, dtype: float64

# %%
plt.plot(ageGrp, label='linear')

plt.show()

# %% [markdown]
# The slop above showed us that survival rate of children was the highest followed by middled aged.

# %% [markdown]
# **Conclusion**
#
# Taking a deep dive into Matplotlib python package was really worth it as it opened our eyes to beautiful ways that we can tell stories using visuals.
#
# We got to know different classes and types of Matplotlib plot that can be used to pass information across. The few plots shown above did not even scratch on how wide/broad we can use Matplotlib.
